# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

X = [1, 2, 3, 4, 5]
Y = [3, 4, 7, 9, 8]

plt.style.use("default")
plt.plot(X, Y) 
plt.title("Oscar Movie Revenue")
# plt.show() # In Jupyter, plt.show() forces the title and plot to merge
# Out:
# Text(0.5, 1.0, 'Oscar Movie Revenue')

# %%
# Movies Data

# Oscar Winner Movies
oscar_movies = [
    "The Dark Knight", 
    "The Hurt Locker",  
    "The King's Speech", 
    "The Artist",     
    "Argo"
]
oscar_years = [2008, 2009, 2010, 2011, 2012]
oscar_revenue = [1005, 170, 427, 133, 232]  # in $M

plt.title("Oscar Movie Revenue")
plt.plot(oscar_years,oscar_revenue)

plt.xlabel("Years")
plt.ylabel("score")
# Out:
# Text(0, 0.5, 'score')

# %%
Nudmienon_oscar_movies = ["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
non_oscar_years = [2008, 2009, 2010, 2011, 2012]
non_oscar_revenue = [378, 2788, 829, 185, 275]  # in $M

plt.plot(oscar_years,oscar_revenue, label="oscar movies")
plt.plot(non_oscar_years, non_oscar_revenue,label="non-oscar movies" )
plt.xlabel("Years") 
plt.ylabel("Revenue")
plt.title("Movies analysis")
plt.legend()

# %%
# format strings
plt.plot(oscar_years,oscar_revenue, linestyle="--", marker="<" ,color="red")
plt.plot(non_oscar_years, non_oscar_revenue ,"o--b", linewidth=0.2 )  #Marker linestyle color

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
movies = [
    "The Dark Knight", 
    "The Hurt Locker",  
    "The King's Speech", 
    "The Artist",     
    "Argo"
]

revenue = [1005, 170, 427, 133, 232]
# plt.style.use('dark_background')
with plt.xkcd():  # cartoonish look
    # plt.style.use('ggplot')
    plt.plot(movies, revenue)
    # plt.tight_layout() # for x axis proper spacing

    # plt.savefig("abc.png") # save graph as png
    # plt.grid()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# ...

# %% [markdown]
# ## Bar chart

# %%
# Bar charts
movies = [
    "The Dark Knight", 
    "The Hurt Locker",  
    "The King's Speech", 
    "The Artist",     
    "Argo"
]
y = [2008, 2009, 2010, 2011, 2012]
r = [1005, 170, 427, 133, 232]  # in $M

plt.title("Yearly revenue of movies")
plt.bar(y, r, color="purple")
plt.xlabel("Years")
plt.ylabel("Revenue (in $M)")


# Add labels on top of bars
for i in range(len(revenue)):
    plt.text(y[i], r[i] + 20, str(revenue[i]), ha="center", color="green")  
    # text(pos of text acc to x-axis, pos of y, text, alignment)

plt.ylim(0, max(revenue)+100) #lower, upper limit - add space
plt.show()

# %%
# comparing data with bar charts
oscar_movies = ["The Dark Knight","The Hurt Locker","The King's Speech","The Artist","Argo"]
oscar_revenue = [1005, 170, 427, 133, 232]  # in $M

non_oscar_movies = ["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
non_oscar_revenue = [378, 2788, 829, 185, 275]  # in $M

years = [2008, 2009, 2010, 2011, 2012]

# Plotting Bar Chart
import numpy as np
x = np.arange(len(years))
width = 0.25

# plt.bar(x-width/2, oscar_revenue, width, label="Oscar")
# plt.bar(x+width/2, non_oscar_revenue, width, label="Non-Oscar")

plt.bar(x-width, oscar_revenue, width, label="Oscar")
plt.bar(x, oscar_revenue, width, label="Oscar-mid")
plt.bar(x+width, non_oscar_revenue, width, label="Non-Oscar")

plt.xlabel("Years")
plt.ylabel("Revenue (in $M)")
plt.title("Yearly revenue of Oscar vs Non-Oscar movies")
plt.legend()
plt.tight_layout()

plt.xticks(x, years) # to show x-axis labels
# Out:
# ([<matplotlib.axis.XTick at 0x19ecdf1a0d0>,
# ...
#  [Text(0, 0, '2008'),
#   Text(1, 0, '2009'),
#   Text(2, 0, '2010'),
#   Text(3, 0, '2011'),
#   Text(4, 0, '2012')])

# %%
# Horizontal Bar Chart
oscar_movies = ["The Dark Knight","The Hurt Locker","The King's Speech","The Artist","Argo"]
oscar_revenue = [1005, 170, 427, 133, 232]  # in $M

non_oscar_movies = ["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
non_oscar_revenue = [378, 2788, 829, 185, 275]  # in $M

years = [2008, 2009, 2010, 2011, 2012]

# Plotting
# y = np.arange(len(years))
plt.barh(oscar_movies, oscar_revenue)
plt.xlabel("Revenue")
plt.ylabel("Movie")
plt.title("Revenue for each Movie")
# Out:
# Text(0.5, 1.0, 'Revenue for each Movie')

# %%
# Scatter Plots
people = ["Person A", "Person B", "Person C", "Person D", "Person E", 
          "Person F", "Person G", "Person H", "Person I", "Person J"]
age = [22, 25, 30, 35, 40, 45, 50, 55, 60, 65]
blood_pressure = [110, 115, 120, 122, 125, 130, 135, 123, 145, 150]

# plot
plt.scatter(age, blood_pressure, color="red")

plt.title("Age vs Blood Pressure")
plt.xlabel("Age")
plt.ylabel("Blood Pressure")
# Out:
# Text(0, 0.5, 'Blood Pressure')

# %%
# Scatter Plots
people = ["Person A", "Person B", "Person C", "Person D", "Person E", 
          "Person F", "Person G", "Person H", "Person I", "Person J"]
age = [22, 25, 30, 35, 40, 45, 50, 55, 60, 65]
blood_pressure = [110, 115, 120, 122, 125, 130, 135, 123, 145, 150]

# plot
# plt.scatter(age, blood_pressure, color="red")

plt.title("Age vs Blood Pressure")
plt.xlabel("Age")
plt.ylabel("Blood Pressure")
plt.grid()

# Customizing plots
colors = ["green" if bp<135 else "red" for bp in blood_pressure]
sizes = blood_pressure
plt.scatter(age, blood_pressure, color=colors, s=sizes, marker='o', alpha=0.5)

# plt.scatter(age, blood_pressure, c=blood_pressure, cmap="plasma")
plt.scatter(age, blood_pressure)# makes more sense

plt.colorbar(label="BP")

# %%
# anotation

# %%
# Scatter Plots
people = ["Person A", "Person B", "Person C", "Person D", "Person E", 
          "Person F", "Person G", "Person H", "Person I", "Person J"]
age = [22, 25, 30, 35, 40, 45, 50, 55, 60, 65]
blood_pressure = [110, 115, 120, 122, 125, 130, 135, 123, 145, 150]

# plot
# plt.scatter(age, blood_pressure, color="red")

plt.title("Age vs Blood Pressure")
plt.xlabel("Age")
plt.ylabel("Blood Pressure")
plt.grid()

# Customizing plots
colors = ["green" if bp<135 else "red" for bp in blood_pressure]
sizes = blood_pressure
plt.scatter(age, blood_pressure, color=colors, s=sizes, marker='o', alpha=0.5)

# plt.scatter(age, blood_pressure, c=blood_pressure, cmap="plasma")
plt.scatter(age, blood_pressure, c=blood_pressure)# makes more sense

plt.colorbar(label="BP")


for i in range(len(age)):
    plt.annotate(people[i], xy=(age[i], blood_pressure[i]))
plt.xlim(min(age), max(age)+10)
# Out:
# (22.0, 75.0)
