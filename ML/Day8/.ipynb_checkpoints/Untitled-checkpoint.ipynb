# %%
import json

def load_data(filename):
    with open(filename, "r") as f:
        data = json.load(f)
    return data

# %%
data = load_data("store_data.json")
print(data)
print(type(data))
# Out:
# [{'name': 'Alice', 'rating': '5', 'feedback': 'Great product!', 'age': 25}, {'name': 'Bob', 'rating': 'four', 'feedback': 'ok but late Delivery', 'age': 30}, {'name': 'Charlie', 'rating': '5 ', 'feedback': 'BAD EXPERIENCE', 'age': 35}, {'name': 'Diana', 'rating': 'three', 'feedback': 'Loved it!', 'age': 28}, {'name': 'Eve', 'rating': '3', 'feedback': 'Average - could be better', 'age': 20}, {'name': 'Alice', 'rating': '5', 'feedback': 'Great product again!', 'age': 25}]
# <class 'list'>

# %%
# data cleaning
def view_data(data):
    for user in data:
        print(user)

# %%
view_data(data)
# Out:
# {'name': 'Alice', 'rating': '5', 'feedback': 'Great product!', 'age': 25}
# {'name': 'Bob', 'rating': 'four', 'feedback': 'ok but late Delivery', 'age': 30}
# {'name': 'Charlie', 'rating': '5 ', 'feedback': 'BAD EXPERIENCE', 'age': 35}
# {'name': 'Diana', 'rating': 'three', 'feedback': 'Loved it!', 'age': 28}
# {'name': 'Eve', 'rating': '3', 'feedback': 'Average - could be better', 'age': 20}
# {'name': 'Alice', 'rating': '5', 'feedback': 'Great product again!', 'age': 25}

# %%
# clean data
def clean_data(data):
    text_to_num = {"one":1, "two":2, "three":3, "four":4, "five":5}

    for users in data:
        raw_rating = users["rating"].strip().trim()
        print(raw_rating)
        if(raw_rating in text_to_num):
            raw_rating = text_to_num[raw_rating]
        users["rating"] = raw_rating

# %%
clean_data(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 clean_data(data)
#
# Cell In[71], line 6, in clean_data(data)
#       3 text_to_num = {"one":1, "two":2, "three":3, "four":4, "five":5}
#       5 for users in data:
# ----> 6     raw_rating = users["rating"].strip().trim()
#       7     print(raw_rating)
#       8     if(raw_rating in text_to_num):
#
# AttributeError: 'str' object has no attribute 'trim'

# %%
view_data(data)
# Out:
# {'name': 'Alice', 'rating': '5', 'feedback': 'Great product!', 'age': 25}
# {'name': 'Bob', 'rating': 4, 'feedback': 'ok but late Delivery', 'age': 30}
# {'name': 'Charlie', 'rating': '5 ', 'feedback': 'BAD EXPERIENCE', 'age': 35}
# {'name': 'Diana', 'rating': 3, 'feedback': 'Loved it!', 'age': 28}
# {'name': 'Eve', 'rating': '3', 'feedback': 'Average - could be better', 'age': 20}
# {'name': 'Alice', 'rating': '5', 'feedback': 'Great product again!', 'age': 25}
